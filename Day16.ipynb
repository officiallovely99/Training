# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.drop(columns = ['Alley','MasVnrType'])
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
df_new = df[['OverallQual','GrLivArea','TotalBsmtSF','YearBuilt','GarageCars','GarageArea','1stFlrSF','FullBath','TotRmsAbvGrd','Fireplaces','BsmtQual','KitchenQual','Neighborhood','ExterQual','LotArea','YearRemodAdd']]

# %%
df_new.shape
# Out:
# (1460, 16)

# %%
df_new.head()
# Out:
#    OverallQual  GrLivArea  TotalBsmtSF  YearBuilt  GarageCars  GarageArea  \
# 0            7       1710          856       2003           2         548
# 1            6       1262         1262       1976           2         460
# 2            7       1786          920       2001           2         608
# 3            7       1717          756       1915           3         642
# 4            8       2198         1145       2000           3         836
#
#    1stFlrSF  FullBath  TotRmsAbvGrd  Fireplaces BsmtQual KitchenQual  \
# 0       856         2             8           0       Gd          Gd
# 1      1262         2             6           1       Gd          TA
# 2       920         2             6           1       Gd          Gd
# 3       961         1             7           1       TA          Gd
# 4      1145         2             9           1       Gd          Gd
#
#   Neighborhood ExterQual  LotArea  YearRemodAdd
# 0      CollgCr        Gd     8450          2003
# ...

# %%
df_new['SalePrice'] = df['SalePrice']
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5116\2820430433.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['SalePrice'] = df['SalePrice']

# %%
df_new
# Out:
#       OverallQual  GrLivArea  TotalBsmtSF  YearBuilt  GarageCars  GarageArea  \
# 0               7       1710          856       2003           2         548
# 1               6       1262         1262       1976           2         460
# 2               7       1786          920       2001           2         608
# 3               7       1717          756       1915           3         642
# 4               8       2198         1145       2000           3         836
# ...           ...        ...          ...        ...         ...         ...
# 1455            6       1647          953       1999           2         460
# 1456            6       2073         1542       1978           2         500
# 1457            7       2340         1152       1941           1         252
# 1458            5       1078         1078       1950           1         240
# 1459            5       1256         1256       1965           1         276
#
# ...

# %%
df_new.isnull().sum()
# Out:
# OverallQual      0
# GrLivArea        0
# TotalBsmtSF      0
# YearBuilt        0
# GarageCars       0
# GarageArea       0
# 1stFlrSF         0
# FullBath         0
# TotRmsAbvGrd     0
# Fireplaces       0
# BsmtQual        37
# KitchenQual      0
# Neighborhood     0
# ExterQual        0
# LotArea          0
# YearRemodAdd     0
# SalePrice        0
# dtype: int64

# %%
df_new['BsmtQual'].value_counts()
# Out:
# BsmtQual
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: count, dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
sm = SimpleImputer(strategy="constant",fill_value='Gd')

# %%
sm.fit(df_new[['BsmtQual']])
# Out:
# SimpleImputer(fill_value='Gd', strategy='constant')

# %%
sm.transform(df_new[['BsmtQual']])[:,0]
# Out:
# array(['Gd', 'Gd', 'Gd', ..., 'TA', 'TA', 'TA'], dtype=object)

# %%
df_new['BsmtQual'] = sm.transform(df_new[['BsmtQual']])[:,0]
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5116\1134521311.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['BsmtQual'] = sm.transform(df_new[['BsmtQual']])[:,0]

# %%
df_new.isnull().sum()
# Out:
# OverallQual     0
# GrLivArea       0
# TotalBsmtSF     0
# YearBuilt       0
# GarageCars      0
# GarageArea      0
# 1stFlrSF        0
# FullBath        0
# TotRmsAbvGrd    0
# Fireplaces      0
# BsmtQual        0
# KitchenQual     0
# Neighborhood    0
# ExterQual       0
# LotArea         0
# YearRemodAdd    0
# SalePrice       0
# dtype: int64

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OverallQual   1460 non-null   int64
#  1   GrLivArea     1460 non-null   int64
#  2   TotalBsmtSF   1460 non-null   int64
#  3   YearBuilt     1460 non-null   int64
#  4   GarageCars    1460 non-null   int64
#  5   GarageArea    1460 non-null   int64
#  6   1stFlrSF      1460 non-null   int64
#  7   FullBath      1460 non-null   int64
#  8   TotRmsAbvGrd  1460 non-null   int64
#  9   Fireplaces    1460 non-null   int64
#  10  BsmtQual      1460 non-null   object
#  11  KitchenQual   1460 non-null   object
#  12  Neighborhood  1460 non-null   object
#  13  ExterQual     1460 non-null   object
#  14  LotArea       1460 non-null   int64
#  15  YearRemodAdd  1460 non-null   int64
#  16  SalePrice     1460 non-null   int64
# dtypes: int64(13), object(4)
# memory usage: 194.0+ KB

# %%
df_new.describe()
# Out:
#        OverallQual    GrLivArea  TotalBsmtSF    YearBuilt   GarageCars  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      6.099315  1515.463699  1057.429452  1971.267808     1.767123
# std       1.382997   525.480383   438.705324    30.202904     0.747315
# min       1.000000   334.000000     0.000000  1872.000000     0.000000
# 25%       5.000000  1129.500000   795.750000  1954.000000     1.000000
# 50%       6.000000  1464.000000   991.500000  1973.000000     2.000000
# 75%       7.000000  1776.750000  1298.250000  2000.000000     2.000000
# max      10.000000  5642.000000  6110.000000  2010.000000     4.000000
#
#         GarageArea     1stFlrSF     FullBath  TotRmsAbvGrd   Fireplaces  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean    472.980137  1162.626712     1.565068      6.517808     0.613014
# std     213.804841   386.587738     0.550916      1.625393     0.644666
# ...

# %%
mt = df_new.corr(numeric_only = True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(mt,annot = True, fmt = '.1f',cmap ='summer')
# Out:
# <Axes: >

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Load the digits dataset
digits = load_digits()
X, y = digits.data, digits.target

# %%
y
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
plt.figure(figsize=(10, 3))
for i in range(9):
    plt.subplot(2, 5, i+1)
    plt.imshow(digits.images[i], cmap='gray')
    plt.title(f"Label: {digits.target[i]}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
data_new = pd.DataFrame(X,columns = digits.feature_names)

# %%
data_new.sample(10)
# Out:
#       pixel_0_0  pixel_0_1  pixel_0_2  pixel_0_3  pixel_0_4  pixel_0_5  \
# 1232        0.0        2.0       11.0       16.0       15.0        6.0
# 27          0.0        0.0        0.0        8.0       14.0       14.0
# 1399        0.0        0.0        3.0       13.0       16.0       16.0
# 1450        0.0        0.0        8.0        9.0        8.0       12.0
# 122         0.0        0.0        3.0        6.0       14.0        5.0
# 1240        0.0        3.0       12.0       15.0       16.0       16.0
# 528         0.0        0.0        5.0       16.0       14.0        2.0
# 1167        0.0        0.0        3.0       14.0        9.0        3.0
# 801         0.0        2.0       12.0       13.0       16.0       16.0
# 1710        0.0        0.0        3.0       12.0       16.0       16.0
#
#       pixel_0_6  pixel_0_7  pixel_1_0  pixel_1_1  ...  pixel_6_6  pixel_6_7  \
# 1232        0.0        0.0        0.0       11.0  ...        4.0        0.0
# ...

# %%
data_new['target'] = digits.target

# %%
data_new.shape
# Out:
# (1797, 65)

# %%
X_train, X_test, y_train, y_test = train_test_split(data_new.drop(columns = ['target']), data_new['target'], test_size=0.3, random_state=4)

# %%
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression(
    multi_class='multinomial',
    max_iter=10000
)
log_model.fit(X_train, y_train)
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=10000, multi_class='multinomial')

# %%
y_pred = log_model.predict(X_test)

# %%
# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Classification Report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=digits.target_names,
            yticklabels=digits.target_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Accuracy: 0.9666666666666667
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        53
#            1       0.89      0.98      0.93        51
#            2       0.98      1.00      0.99        54
#            3       0.98      0.93      0.95        55
#            4       0.98      0.98      0.98        54
#            5       0.95      0.97      0.96        58
#            6       1.00      0.96      0.98        52
#            7       1.00      0.95      0.97        55
#            8       0.96      0.95      0.95        55
#            9       0.93      0.96      0.94        53
#
#     accuracy                           0.97       540
#    macro avg       0.97      0.97      0.97       540
# weighted avg       0.97      0.97      0.97       540

# %%
# Show 5 test images with predictions
plt.figure(figsize=(10, 3))
li = [0,1,2,3,4,5]
for i,j in zip(X_test.index[:5],li):
    plt.subplot(1, 5, j+1)
    plt.imshow(X_test.loc[i].values.reshape(8, 8), cmap='gray')
    plt.title(f"Pred: {y_pred[j]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
