# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score , classification_report , confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

#load digits the dataset
digits = load_digits()
x,y = digits.data , digits.target

# %%
y
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
plt.figure(figsize=(10,3))
for i in range (10):
    plt.subplot(2,5,i+1)
    plt.imshow(digits.images[i],cmap='grey')
    plt.title(f"label : {digits.target[i]}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
data_new = pd.DataFrame(x,columns = digits.feature_names)

# %%
data_new.shape
# Out:
# (1797, 64)

# %%
plt.imshow(data_new.loc[9].values.reshape(8,8) , cmap='grey')

# %%
x_train,x_test,y_train,y_test, = train_test_split(data_new.drop(columns = ['target']),data_new['target'], test_size = 0.3 ,random_state = 4)

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Sample data (X = hours studied, Y = exam score)
X = np.array([[1], [2], [3], [4], [5]])
Y = np.array([40, 50, 60, 70, 80])

# Create a linear regression model
model = LinearRegression()

# Train (fit) the model
model.fit(X, Y)

# Predict for new values
X_test = np.array([[6]])
Y_pred = model.predict(X_test)

print("Predicted Score for 6 hours:", Y_pred[0])
print("Slope (m):", model.coef_[0])
print("Intercept (c):", model.intercept_)

# Plot
plt.scatter(X, Y, color='blue', label='Actual Data')
plt.plot(X, model.predict(X), color='red', label='Best Fit Line')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.legend()
plt.show()
# Out:
# Predicted Score for 6 hours: 90.0
# Slope (m): 10.000000000000002
# Intercept (c): 29.999999999999993
