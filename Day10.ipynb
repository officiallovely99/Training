# %%
import pandas as pd
df = pd.read_csv("matches.csv")
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
import numpy as np
# d = (df['result'] == 'runs') & (df['result_margin'] == df['result_margin'].max())

# %%
MatchCount=df.value_counts("city")
print(MatchCount)
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Visakhapatnam      15
# Durban             15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Sharjah            10
# Rajkot             10
# Navi Mumbai         9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Port Elizabeth      7
# Cuttack             7
# Cape Town           7
# Raipur              6
# Mohali              5
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# Guwahati            3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
data = df[['result' ,'result_margin','winner']]
data.groupby('result').max()
# Out:
#            result_margin               winner
# result
# no result            NaN                  NaN
# runs               146.0  Sunrisers Hyderabad
# tie                  NaN  Sunrisers Hyderabad
# wickets             10.0  Sunrisers Hyderabad

# %%
MatchType=df['match_type'].unique()
print(MatchType)
# Out:
# ['League' 'Semi Final' 'Final' '3rd Place Play-Off' 'Qualifier 1'
#  'Elimination Final' 'Qualifier 2' 'Eliminator']

# %%
data1 = pd.concat([df['umpire1'],df['umpire2']])
data1
data1.value_counts().sort_values()
# Out:
# Subroto Das          1
# SD Ranade            2
# AG Wharf             2
# K Bharatan           3
# TH Wijewardene       5
#                   ...
# C Shamshuddin       88
# HDPK Dharmasena     98
# Nitin Menon        104
# AK Chaudhary       131
# S Ravi             131
# Name: count, Length: 70, dtype: int64

# %%
data1.value_counts().max()
# Out:
# 131

# %%
data2 =  df[df['toss_winner'] == df['winner']]
data2[['toss_winner','winner']].groupby('winner').value_counts().sort_values()
# Out:
# winner                       toss_winner
# Rising Pune Supergiants      Rising Pune Supergiants         3
# Pune Warriors                Pune Warriors                   3
# Kochi Tuskers Kerala         Kochi Tuskers Kerala            4
# Royal Challengers Bengaluru  Royal Challengers Bengaluru     4
# Rising Pune Supergiant       Rising Pune Supergiant          5
# Punjab Kings                 Punjab Kings                    9
# Lucknow Super Giants         Lucknow Super Giants           10
# Gujarat Lions                Gujarat Lions                  10
# Gujarat Titans               Gujarat Titans                 14
# Deccan Chargers              Deccan Chargers                19
# Delhi Capitals               Delhi Capitals                 26
# Delhi Daredevils             Delhi Daredevils               35
# Kings XI Punjab              Kings XI Punjab                36
# Sunrisers Hyderabad          Sunrisers Hyderabad            38
# ...

# %%
value =  df.groupby(df['toss_decision'])['toss_decision'].count()
key = df['toss_decision'].unique()

# %%
import matplotlib.pyplot as plt
#plt.title('
plt.bar([ 'bat', 'feild'], value)
# Out:
# <BarContainer object of 2 artists>

# %%
MostPlayerMatch=df['player_of_match'].value_counts()
print(MostPlayerMatch)
MostPlayerMatch_1=df['player_of_match'].value_counts().idxmax()
print("Maximum number of time player of match with",MostPlayerMatch_1)
# Out:
# player_of_match
# AB de Villiers       25
# CH Gayle             22
# RG Sharma            19
# DA Warner            18
# V Kohli              18
#                      ..
# NV Ojha               1
# KV Sharma             1
# Washington Sundar     1
# PD Collingwood        1
# Shahbaz Ahmed         1
# Name: count, Length: 291, dtype: int64
# Maximum number of time player of match with AB de Villiers

# %%
FreqTossDecision=df['toss_decision'].value_counts()
print(FreqTossDecision)
# Out:
# toss_decision
# field    704
# bat      391
# Name: count, dtype: int64

# %%
df[df['venue'] == 'Wankhede Stadium']
# Out:
#           id   season    city        date  match_type player_of_match  \
# 3     335985  2007/08  Mumbai  2008-04-20      League      MV Boucher
# 35    336018  2007/08  Mumbai  2008-05-14      League   ST Jayasuriya
# 37    336021  2007/08  Mumbai  2008-05-16      League      SM Pollock
# 44    336028  2007/08  Mumbai  2008-05-21      League        SE Marsh
# 55    336038  2007/08  Mumbai  2008-05-30  Semi Final       SR Watson
# ..       ...      ...     ...         ...         ...             ...
# 719  1178399     2019  Mumbai  2019-04-10      League      KA Pollard
# 722  1178402     2019  Mumbai  2019-04-13      League      JC Buttler
# 726  1178406     2019  Mumbai  2019-04-15      League      SL Malinga
# 746  1178426     2019  Mumbai  2019-05-02      League       JJ Bumrah
# 751  1178431     2019  Mumbai  2019-05-05      League       HH Pandya
#
#                 venue                        team1  \
# 3    Wankhede Stadium               Mumbai Indians
# ...

# %%
TossWinerAlsoMatchWin=df[df['toss_winner'] == df['winner']].shape[0]
print(TossWinerAlsoMatchWin)
# Out:
# 554

# %%
df[df['result_margin'] > 50]
# Out:
#            id   season           city        date  match_type player_of_match  \
# 0      335982  2007/08      Bangalore  2008-04-18      League     BB McCullum
# 9      335991  2007/08     Chandigarh  2008-04-25      League   KC Sangakkara
# 39     336023  2007/08         Jaipur  2008-05-17      League        GC Smith
# 55     336038  2007/08         Mumbai  2008-05-30  Semi Final       SR Watson
# 59     392182     2009      Cape Town  2009-04-18      League        R Dravid
# ...       ...      ...            ...         ...         ...             ...
# 1039  1422134     2024  Visakhapatnam  2024-04-03      League       SP Narine
# 1058  1426273     2024          Delhi  2024-04-20      League         TM Head
# 1069  1426284     2024        Chennai  2024-04-28      League      RD Gaikwad
# 1077  1426292     2024        Lucknow  2024-05-05      League       SP Narine
# 1081  1426296     2024     Dharamsala  2024-05-09      League         V Kohli
#
# ...

# %%
import matplotlib.pyplot as plt
df['season'].value_counts().plot(kind='bar')
plt.show()

# %%
iplmat['toss_decision'].value_counts().plot(kind='pie', autopct='%1.1f%%')

# %%
iplmat['city'].value_counts().idxmax()
